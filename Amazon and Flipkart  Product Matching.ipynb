# %% [markdown]
# <a href="https://colab.research.google.com/github/pratyushnishchal007/Product-matching/blob/main/Amazon%20and%20Flipkart%20%20Product%20Matching.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fuzzymatcher
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import modules
import numpy as np
import pandas as pd
import fuzzymatcher

# %%
#Loading the data set
amazon_data=pd.read_csv('amz_com-ecommerce_sample.csv',encoding= 'unicode_escape')
flipkart_data=pd.read_csv('flipkart_com-ecommerce_sample.csv',encoding= 'unicode_escape')

# %%
amazon_data.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
flipkart_data.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
# to get the column names of amazon data
amazon_data.columns
# Out:
# Index(['uniq_id', 'crawl_timestamp', 'product_url', 'product_name',
#        'product_category_tree', 'pid', 'retail_price', 'discounted_price',
#        'image', 'is_FK_Advantage_product', 'description', 'product_rating',
#        'overall_rating', 'brand', 'product_specifications'],
#       dtype='object')

# %%
amazon_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             20000 non-null  int64
#  7   discounted_price         20000 non-null  int64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
flipkart_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   uniq_id                  20000 non-null  object
#  1   crawl_timestamp          20000 non-null  object
#  2   product_url              20000 non-null  object
#  3   product_name             20000 non-null  object
#  4   product_category_tree    20000 non-null  object
#  5   pid                      20000 non-null  object
#  6   retail_price             19922 non-null  float64
#  7   discounted_price         19922 non-null  float64
#  8   image                    19997 non-null  object
#  9   is_FK_Advantage_product  20000 non-null  bool
#  10  description              19998 non-null  object
#  11  product_rating           20000 non-null  object
#  12  overall_rating           20000 non-null  object
#  13  brand                    14136 non-null  object
# ...

# %%
# checking how many NA values are there in retail_price column
flipkart_data['retail_price'].isna().sum()
# Out:
# 78

# %%
# checking how many NA values are there in discounted_price column
flipkart_data['discounted_price'].isna().sum()
# Out:
# 78

# %%
# Finding which row has NA values in retail_price column.
flipkart_data[flipkart_data['retail_price'].isnull()].index
# Out:
# Int64Index([   12,    21,    76,   812,  1318,  1734,  2977,  3233,  3404,
#              3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
#              7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190,
#              8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
#             10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393,
#             11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
#             12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541,
#             12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
#             16487, 16762, 17634, 19543, 19599, 19622],
#            dtype='int64')

# %%
# Finding which row has NA values in discounted_price column.
flipkart_data[flipkart_data['discounted_price'].isnull()].index
# Out:
# Int64Index([   12,    21,    76,   812,  1318,  1734,  2977,  3233,  3404,
#              3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
#              7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190,
#              8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
#             10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393,
#             11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
#             12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541,
#             12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
#             16487, 16762, 17634, 19543, 19599, 19622],
#            dtype='int64')

# %%
# Droping the rows which have NA values from flipkart data
flipkart_data.drop([12,    21,    76,   812,  1318,  1734,  2977,  3233,  3404,
             3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
             7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190,
             8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
            10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393,
            11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
            12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541,
            12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
            16487, 16762, 17634, 19543, 19599, 19622],axis=0,inplace=True)

# %%
# Droping the rows which have NA values from amazon data
amazon_data.drop([12,    21,    76,   812,  1318,  1734,  2977,  3233,  3404,
             3889,  4590,  5644,  5696,  5967,  6248,  6271,  6601,  6874,
             7396,  7646,  7725,  8027,  8040,  8117,  8176,  8187,  8190,
             8267,  8383,  8448,  8500,  8918,  9069, 10117, 10135, 10272,
            10669, 10745, 11072, 11118, 11319, 11337, 11379, 11383, 11393,
            11420, 11432, 11499, 11567, 11682, 11961, 11962, 11981, 12052,
            12120, 12226, 12274, 12336, 12395, 12396, 12401, 12433, 12541,
            12572, 12690, 12734, 12933, 13123, 13354, 16143, 16296, 16312,
            16487, 16762, 17634, 19543, 19599, 19622],axis=0,inplace=True)

# %%
df=fuzzymatcher.fuzzy_left_join(amazon_data,flipkart_data,left_on='product_name',right_on='product_name')

# %%
df
# Out:
#         best_match_score   __id_left   __id_right  \
# 0               1.109848      0_left      0_right
# 6               1.101432      1_left      1_right
# 10              0.511359      2_left      2_right
# 11              1.109848      3_left      0_right
# 17              1.485005      4_left      4_right
# ...                  ...         ...          ...
# 150826          1.003691  19917_left  19721_right
# 150876          1.224607  19918_left  19720_right
# 150926          0.992232  19919_left  19711_right
# 150954          0.992232  19920_left  19711_right
# 150982          0.992232  19921_left  19711_right
#
#                             uniq_id_left       crawl_timestamp_left  \
# 0       c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 6       7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 10      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 11      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# ...

# %%
df.columns
# Out:
# Index(['best_match_score', '__id_left', '__id_right', 'uniq_id_left',
#        'crawl_timestamp_left', 'product_url_left', 'product_name_left',
#        'product_category_tree_left', 'pid_left', 'retail_price_left',
#        'discounted_price_left', 'image_left', 'is_FK_Advantage_product_left',
#        'description_left', 'product_rating_left', 'overall_rating_left',
#        'brand_left', 'product_specifications_left', 'uniq_id_right',
#        'crawl_timestamp_right', 'product_url_right', 'product_name_right',
#        'product_category_tree_right', 'pid_right', 'retail_price_right',
#        'discounted_price_right', 'image_right',
#        'is_FK_Advantage_product_right', 'description_right',
#        'product_rating_right', 'overall_rating_right', 'brand_right',
#        'product_specifications_right'],
#       dtype='object')

# %%
df=df.drop(columns=['best_match_score', '__id_left', '__id_right', 'uniq_id_left',
       'crawl_timestamp_left', 'product_url_left',
       'product_category_tree_left', 'pid_left',
        'image_left', 'is_FK_Advantage_product_left',
       'description_left', 'product_rating_left', 'overall_rating_left',
       'brand_left', 'product_specifications_left', 'uniq_id_right',
       'crawl_timestamp_right', 'product_url_right',
       'product_category_tree_right', 'pid_right',
        'image_right', 'is_FK_Advantage_product_right', 'description_right',
       'product_rating_right', 'overall_rating_right', 'brand_right',
       'product_specifications_right'])

# %%
df
# Out:
#                               product_name_left  retail_price_left  \
# 0           Alisha Solid Women's Cycling Shorts                982
# 6           FabHomeDecor Fabric Double Sofa Bed              32143
# 10                                   AW Bellies                991
# 11          Alisha Solid Women's Cycling Shorts                694
# 17        Sicons All Purpose Arnica Dog Shampoo                208
# ...                                         ...                ...
# 150826           WALLDESIGN SMALL VINYL STICKER               1498
# 150876  WALLMANTRA LARGE VINYL STICKERS STICKER               1415
# 150926  ELITE COLLECTION MEDIUM ACRYLIC STICKER               1284
# 150954  ELITE COLLECTION MEDIUM ACRYLIC STICKER               1492
# 150982  ELITE COLLECTION MEDIUM ACRYLIC STICKER               1484
#
#         discounted_price_left                       product_name_right  \
# 0                         438      Alisha Solid Women's Cycling Shorts
# ...

# %%
df.columns.values[0] = "Product name in Flipkart"
df.columns.values[1] = "Retail Price in Flipkart"
df.columns.values[2] = "Discounted Price in Flipkart"
df.columns.values[3] = "Product name in Amazon"
df.columns.values[4] = "Retail Price in Amazon"
df.columns.values[5] = "Discounted Price in Amazon"

# %%
df
# Out:
#                        Product name in Flipkart  Retail Price in Flipkart  \
# 0           Alisha Solid Women's Cycling Shorts                       982
# 6           FabHomeDecor Fabric Double Sofa Bed                     32143
# 10                                   AW Bellies                       991
# 11          Alisha Solid Women's Cycling Shorts                       694
# 17        Sicons All Purpose Arnica Dog Shampoo                       208
# ...                                         ...                       ...
# 150826           WALLDESIGN SMALL VINYL STICKER                      1498
# 150876  WALLMANTRA LARGE VINYL STICKERS STICKER                      1415
# 150926  ELITE COLLECTION MEDIUM ACRYLIC STICKER                      1284
# 150954  ELITE COLLECTION MEDIUM ACRYLIC STICKER                      1492
# 150982  ELITE COLLECTION MEDIUM ACRYLIC STICKER                      1484
#
#         Discounted Price in Flipkart                   Product name in Amazon  \
# ...
